# %% [markdown]
# # 非条件GAN
#
# 同济子豪兄 2023-3-6

# %% [markdown]
# ## 进入 MMEditing 主目录

# %%
import os
os.chdir('mmediting')

# %% [markdown]
# ## 导入工具包

# %%
import mmcv
from mmedit.edit import MMEdit

from PIL import Image

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## MMEdit实例

# %%
editor = MMEdit('styleganv1')
# Out:
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmediting/styleganv1/styleganv1_ffhq_256_g8_25Mimg_20210407_161748-0094da86.pth
# Switch to evaluation style mode: single
# Switch to evaluation style mode: single
# 03/06 18:40:42 - mmengine - WARNING - Failed to search registry with scope "mmedit" in the "Collate Functions" registry tree. As a workaround, the current "Collate Functions" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmedit" is a correct scope, or whether the registry is initialized.
# /environment/miniconda3/lib/python3.7/site-packages/mmengine/visualization/visualizer.py:166: UserWarning: `Visualizer` backend is not initialized because save_dir is None.
#   warnings.warn('`Visualizer` backend is not initialized '

# %% [markdown]
# ## 输出路径

# %%
out_path = 'outputs/tutorial_unconditional_styleganv1_res.png'

# %% [markdown]
# ## 执行预测

# %%
results = editor.infer(result_out_dir=out_path)

# %%
Image.open(out_path)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1034x260 at 0x7F9A7DF7F8D0>
