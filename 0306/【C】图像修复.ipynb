# %% [markdown]
# # 图像修复
#
# 同济子豪兄 2023-3-6

# %% [markdown]
# ## 进入 MMEditing 主目录

# %%
import os
os.chdir('mmediting')

# %% [markdown]
# ## 导入工具包

# %%
import mmcv
from mmedit.edit import MMEdit

from PIL import Image

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 被破坏的图像

# %%
img_path = 'data/inpainting/celeba_test.png'

# %%
Image.open(img_path)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7F1BC9C77B10>

# %% [markdown]
# ## 被破坏的mask区域

# %%
mask_path = 'data/inpainting/bbox_mask.png'

# %%
Image.open(mask_path)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=256x256 at 0x7F1D5833AFD0>

# %% [markdown]
# ## MMEdit实例

# %%
editor = MMEdit('global_local', model_setting=1)
# Out:
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmediting/inpainting/global_local/gl_256x256_8x12_celeba_20200619-5af0493f.pth
# Downloading: "https://download.openmmlab.com/mmediting/inpainting/global_local/gl_256x256_8x12_celeba_20200619-5af0493f.pth" to /home/featurize/.cache/torch/hub/checkpoints/gl_256x256_8x12_celeba_20200619-5af0493f.pth
# 03/06 18:26:28 - mmengine - WARNING - Failed to search registry with scope "mmedit" in the "Collate Functions" registry tree. As a workaround, the current "Collate Functions" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmedit" is a correct scope, or whether the registry is initialized.
# /environment/miniconda3/lib/python3.7/site-packages/mmengine/visualization/visualizer.py:166: UserWarning: `Visualizer` backend is not initialized because save_dir is None.
#   warnings.warn('`Visualizer` backend is not initialized '

# %% [markdown]
# ## 输出图像路径

# %%
out_path = 'outputs/inpainting/out.jpg'

# %% [markdown]
# ## 执行预测

# %%
results = editor.infer(img=img_path, mask=mask_path, result_out_dir=out_path)

# %%
Image.open(out_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7F1BC6D67C10>
