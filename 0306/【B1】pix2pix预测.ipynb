# %% [markdown]
# # pix2pix预测
#
# 同济子豪兄 2023-3-6

# %% [markdown]
# ## 进入 MMEditing 主目录

# %%
import os
os.chdir('mmediting')

# %% [markdown]
# ## 导入工具包

# %%
from mmedit.edit import MMEdit
from PIL import Image

# %% [markdown]
# ## MMEdit实例

# %%
editor = MMEdit('pix2pix')
# Out:
# Loads checkpoint by http backend from path: https://download.openmmlab.com/mmediting/pix2pix/refactor/pix2pix_vanilla_unet_bn_1x1_80k_facades_20210902_170442-c0958d50.pth
# 03/06 18:07:00 - mmengine - WARNING - Failed to search registry with scope "mmedit" in the "Collate Functions" registry tree. As a workaround, the current "Collate Functions" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmedit" is a correct scope, or whether the registry is initialized.
# /environment/miniconda3/lib/python3.7/site-packages/mmengine/visualization/visualizer.py:166: UserWarning: `Visualizer` backend is not initialized because save_dir is None.
#   warnings.warn('`Visualizer` backend is not initialized '

# %% [markdown]
# ## 指定输入图像和输出图像路径

# %%
input_path = 'data/gt_mask_0.png'
output_path = 'outputs/tutorial_translation_pix2pix_res.jpg'

# %% [markdown]
# ## 执行预测

# %%
results = editor.infer(img=input_path, result_out_dir=output_path)

# %% [markdown]
# ## 展示原图和预测结果

# %%
Image.open(input_path)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=256x256 at 0x7FDCF6FBC810>

# %%
Image.open(output_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7FDCF6B4BB50>
